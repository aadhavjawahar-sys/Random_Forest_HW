# %% [markdown]
# <a href="https://colab.research.google.com/github/aadhavjawahar-sys/Random_Forest_HW/blob/main/random_forest_homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Random Forest Homework:

# %% [markdown]
# As usual, make a copy of this notebook and save it to your own google drive.  Then complete the assignment BY WORKING IN THIS NOTEBOOK.
# - Just add extra code cells and text cells to complete the problems and explain your work
# - Don't create your own new notebook from scratch otherwise you may be missing certain imports and things will be much harder to troubleshoot.

# %% [markdown]
# For this homework assignment, you will compare a decision tree models to random forest models run on breast cancer data to classify tumors as malignant or benign.

# %% [markdown]
# First run the following cell to import most of the necessary things.  Do not edit the following cell.

# %%
### DO NOT EDIT THIS CELL
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# Next, run the following cell without changing it. This cell loads the dataset.
# - For this assignment you will be working with sklearn's breast cancer dataset
#   - This is a data set of tumors
#   - You will classify whether the tumor is malignant or benign
#     - $y = 0$ means it's benign, $y = 1$ means it's malignant.
#   - Here we store the feature matrix in a numpy array called `X` and the target vector in a numy array called `y`.
#   - If you'd like to see what features the different columns of `X` represent, you can run `print(data.feature_names)
#   - The features in this case are all numerical so you don't need to worry about one-hot encoding.

# %%
### DO NOT EDIT THIS CELL
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer()

X = data.data
y = data.target

# %% [markdown]
# For this assignment, I will not give you such a guided outline like previous homeworks.  Instead, your job is to train a decision tree to classify the data. Then, train a random forest to classify the data and compare the two.
#   - Don't forget to split the data into a training set and testing set.
#   - For each model, try to manually adjust hyper parameters to get the best possible result on the testing set.
# Then, write up a brief summary of your results.  Which model were you able to get the best result with? What hyperparameters did you adjust and why do you think that gave you the best result. If there are any other interesting observations you had, explain those as well.
#
# Insert code cells and text cells as necessary to complete this.

# %%
df = pd.DataFrame(X)
df['target'] = y;

df.head()
# Out:
#        0      1       2       3        4        5       6        7       8  \
# 0  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001  0.14710  0.2419
# 1  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869  0.07017  0.1812
# 2  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974  0.12790  0.2069
# 3  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414  0.10520  0.2597
# 4  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980  0.10430  0.1809
#
#          9  ...     21      22      23      24      25      26      27  \
# 0  0.07871  ...  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.05667  ...  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.05999  ...  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.09744  ...  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.05883  ...  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#        28       29  target
# 0  0.4601  0.11890       0
# 1  0.2750  0.08902       0
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=2026,test_size=0.25,stratify=y)

# %%
model_Forest = RandomForestClassifier(max_depth=8, max_features=2, n_estimators=500)

# %%
model_Forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=8, max_features=2, n_estimators=500)

# %%
y_pred_train = model_Forest.predict(X_train)
y_pred_test = model_Forest.predict(X_test)

# %%
print(classification_report(y_train, y_pred_train))
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       159
#            1       1.00      1.00      1.00       267
#
#     accuracy                           1.00       426
#    macro avg       1.00      1.00      1.00       426
# weighted avg       1.00      1.00      1.00       426
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93        53
#            1       0.96      0.97      0.96        90
#
#     accuracy                           0.95       143
#    macro avg       0.95      0.95      0.95       143
# weighted avg       0.95      0.95      0.95       143

# %%
model_tree = DecisionTreeClassifier(max_depth=8)
model_tree.fit(X_train, y_train)
y_pred_train = model_tree.predict(X_train)
y_pred_test = model_tree.predict(X_test)
print(classification_report(y_train, y_pred_train))
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       159
#            1       1.00      1.00      1.00       267
#
#     accuracy                           1.00       426
#    macro avg       1.00      1.00      1.00       426
# weighted avg       1.00      1.00      1.00       426
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88        53
#            1       0.94      0.91      0.93        90
#
#     accuracy                           0.91       143
#    macro avg       0.90      0.91      0.90       143
# weighted avg       0.91      0.91      0.91       143
